# %% [markdown]
# # Open Data Cube Demos
# ## Intersection of these libraries/projects/concepts
# ### Open Data Cube (ODC)
# ### LCMAP (pyccd anyway)
# #### Coordination with Jeff Briden
# 1. **Important** Takeaways from ODC demos of pyccd
# - xarray is not ODC
# - rasterio and gdal are not ODC
# - these libraries along with many others are leveraged by ODC
# 2. ODC is many things - this scope is - ODC in the cloud using USARD
# - looks to be a great tool for ad-hoc science
# - production pipelines will require some optimizing and streamlining
#
# ### Visualization of Complex Data Structures
#
# ## Expected Outcomes
# 1. Continue Refining the **common context** for
#     - leaders, technologists, developers, architects
#
# ---
# 2. Intro to 2019 one year roadmap/plan/sprints for ODC Cloud Engineer == Tony
# http://ga-odc-eros-archive-west.s3.amazonaws.com/temp-plot.html
# 3. Explore components in common between ODC and LCMAP (constrained by cloud vision)
#     - also L8 first; L5 for pyccd ?
#     - USARD tiles and chips
#     - unilateral approaches and limitations
#     - comparison to pixels (rods) delivered by merlin/chipmunk
# 4. Fulfils committment to monthly (regular cadence) status reports
#
# ## Remaining work
# 1. delivering exact same time series from ODC as merlin
#     - L4-L8 as a single series
# 2. Compare pyccd models generated by completely different data and metadata paths

# %% [markdown]
# ![arch simple](../asset/app1.png)

# %% [markdown]
# # ODC specific View
#
# ![arch simple](../asset/appODC1.png)
#
# > If We have time...
#
# ## We will deep dive into the "metadata", "Dataset" list/array/time-series
#
# ### Building a datacube is hard!
#
# #### Once built it is a very powerful tool for data exploration and time series

# %% [markdown]
# # Demo Agenda

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.offline as py

py.init_notebook_mode(connected=True)


df = [
   
    
    dict(Task='Next Steps', Start='2018-11-05 11:50', Finish='2018-11-05 11:59', Resource='Overview'),
    dict(Task='merlin', Start='2018-11-05 11:40', Finish='2018-11-05 11:50', Resource='ODC'),
    dict(Task='Therms', Start='2018-11-05 11:30', Finish='2018-11-05 11:40', Resource='PYCCD'),
    dict(Task='Map Reduce', Start='2018-11-05 11:20', Finish='2018-11-05 11:30', Resource='ODC'),
    dict(Task='Water Detect', Start='2018-11-05 11:10', Finish='2018-11-05 11:20', Resource='Map'),
    dict(Task='Introduction', Start='2018-11-05 11:02', Finish='2018-11-05 11:10:00', Resource='Overview')
]

colors = dict(Strategy = 'rgb(46, 137, 205)',
              Overview = 'rgb(114, 44, 121)',
              Map = 'rgb(198, 47, 105)',
              PYCCD = 'rgb(58, 149, 136)',
              ODC = 'rgb(107, 127, 135)')

fig = ff.create_gantt(df, colors=colors, index_col='Resource', title='Demo Schedule',
                      show_colorbar=True, bar_width=0.3, showgrid_x=True, showgrid_y=True)
py.iplot(fig, show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="70912e6f-94d6-408f-852d-f1fa783ea66f" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("70912e6f-94d6-408f-852d-f1fa783ea66f", [{"type": "scatter", "x": ["2018-11-05 11:50", "2018-11-05 11:59"], "showlegend": false, "name": "", "uid": "8e0addb0-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [0, 0]}, {"type": "scatter", "x": ["2018-11-05 11:40", "2018-11-05 11:50"], "showlegend": false, "name": "", "uid": "8e0addb1-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [1, 1]}, {"type": "scatter", "x": ["2018-11-05 11:30", "2018-11-05 11:40"], "showlegend": false, "name": "", "uid": "8e0addb2-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [2, 2]}, {"type": "scatter", "x": ["2018-11-05 11:20", "2018-11-05 11:30"], "showlegend": false, "name": "", "uid": "8e0addb3-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [3, 3]}, {"type": "scatter", "x": ["2018-11-05 11:10", "2018-11-05 11:20"], "showlegend": false, "name": "", "uid": "8e0addb4-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [4, 4]}, {"type": "scatter", "x": ["2018-11-05 11:02", "2018-11-05 11:10:00"], "showlegend": false, "name": "", "uid": "8e0addb5-ec0c-11e8-99d6-02738673ee84", "marker": {"color": "white"}, "y": [5, 5]}, {"type": "scatter", "x": ["2018-11-05 11:02", "2018-11-05 11:02"], "showlegend": true, "name": "Map", "uid": "8e0addb6-ec0c-11e8-99d6-02738673ee84", "hoverinfo": "none", "marker": {"color": "rgb(198, 47, 105)", "size": 1}, "y": [0, 0]}, {"type": "scatter", "x": ["2018-11-05 11:02", "2018-11-05 11:02"], "showlegend": true, "name": "ODC", "uid": "8e0addb7-ec0c-11e8-99d6-02738673ee84", "hoverinfo": "none", "marker": {"color": "rgb(107, 127, 135)", "size": 1}, "y": [1, 1]}, {"type": "scatter", "x": ["2018-11-05 11:02", "2018-11-05 11:02"], "showlegend": true, "name": "Overview", "uid": "8e0addb8-ec0c-11e8-99d6-02738673ee84", "hoverinfo": "none", "marker": {"color": "rgb(114, 44, 121)", "size": 1}, "y": [2, 2]}, {"type": "scatter", "x": ["2018-11-05 11:02", "2018-11-05 11:02"], "showlegend": true, "name": "PYCCD", "uid": "8e0addb9-ec0c-11e8-99d6-02738673ee84", "hoverinfo": "none", "marker": {"color": "rgb(58, 149, 136)", "size": 1}, "y": [3, 3]}], {"shapes": [{"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:59", "xref": "x", "yref": "y", "x0": "2018-11-05 11:50", "opacity": 1, "fillcolor": "rgb(114, 44, 121)", "y1": 0.3, "y0": -0.3}, {"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:50", "xref": "x", "yref": "y", "x0": "2018-11-05 11:40", "opacity": 1, "fillcolor": "rgb(107, 127, 135)", "y1": 1.3, "y0": 0.7}, {"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:40", "xref": "x", "yref": "y", "x0": "2018-11-05 11:30", "opacity": 1, "fillcolor": "rgb(58, 149, 136)", "y1": 2.3, "y0": 1.7}, {"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:30", "xref": "x", "yref": "y", "x0": "2018-11-05 11:20", "opacity": 1, "fillcolor": "rgb(107, 127, 135)", "y1": 3.3, "y0": 2.7}, {"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:20", "xref": "x", "yref": "y", "x0": "2018-11-05 11:10", "opacity": 1, "fillcolor": "rgb(198, 47, 105)", "y1": 4.3, "y0": 3.7}, {"type": "rect", "line": {"width": 0}, "x1": "2018-11-05 11:10:00", "xref": "x", "yref": "y", "x0": "2018-11-05 11:02", "opacity": 1, "fillcolor": "rgb(114, 44, 121)", "y1": 5.3, "y0": 4.7}], "height": 600, "showlegend": true, "hovermode": "closest", "title": "Demo Schedule", "yaxis": {"zeroline": false, "tickvals": [0, 1, 2, 3, 4, 5], "ticktext": ["Next Steps", "merlin", "Therms", "Map Reduce", "Water Detect", "Introduction"], "showgrid": true, "autorange": false, "range": [-1, 7]}, "xaxis": {"type": "date", "showgrid": true, "zeroline": false, "rangeselector": {"buttons": [{"step": "day", "stepmode": "bac ...

# %% [markdown]
# # Time Permitting - deep dive into Dataset lists

# %% [markdown]
# ![infrastructure overview](../asset/odc1Demo.png)

# %% [markdown]
# # Next Steps
#
# 1. Mexico - espaDog
#     - espa1 - path 40 row 37
#     - Jerad Shaw to use USB Drives - shooting for a Christmas present
#         - 5 x 8 terrabytes each
# 2. add thermal bands for l8 l7 l5 etc
#     - usard-fido - done
#     - BTB10 and BTB6 downloaded via fido
# 3. manage monthly sprints
#     - NEXT lcmap current architecture - deep dive
#         - merlin and perhaps chipmunk
#         - llsrlscd04 - on premise virtual machine
#                - access to cassandra and mesos
#                - access to IW+DS and Science Execution Engine
#     - lcmapi application drivers for deep dive using on-prem equipment
#         - kelsy notebook reviews
#         - tapTool testing
# 4. Longer Term TBD
#     - maybe move to SGT AWS or CHS
#     - ODC as a service
#         - perhaps collection2 in the cloud is a pre-requisite

# %% [markdown]
# # Links dashboard in the cloud
#
#
# http://ec2-52-201-154-0.compute-1.amazonaws.com/data_cube_manager/dataset_types/23/datasets

# %% [markdown]
# # Raster Products
#
# ![raster products](../asset/l2-lcmap-raster-products.png)

# %% [markdown]
# # LCMAP Graphics
#
# ![graphics](../asset/l1-lcmap-graphics.png)

# %%
! ls ../asset
# Out:
# app1.png		  jeffBridenDemo.png		map-reduce.jpg
# appODC1.png		  l1-lcmap-graphics.png		odc1Demo.png
# change_model_save.png	  l2-lcmap-raster-products.png	pyccd_model_start.png
# focused-diffuse-mode.png  lcmap_cubes.png

# %% [markdown]
# # LCMAP cubes
#
# ![graphics](../asset/lcmap_cubes.png)
