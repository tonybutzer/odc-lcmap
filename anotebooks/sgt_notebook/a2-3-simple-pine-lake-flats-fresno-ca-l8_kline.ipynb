# %% [markdown]
# # Example notebook

# %%
import datacube
dc= datacube.Datacube()
# Out:
# Failed to resolve driver datacube.plugins.index::s3aio_index

# %%
# !datacube dataset search product ='l8_kline' |grep id |wc
# Out:
# 2018-11-28 22:24:36,093 17856 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
#     570    1140   23370

# %%
from datetime import datetime
date_range = (
        datetime(2014,1,20),
        datetime(2015,12,31))

# %%
x_lon_extent = (-119.44,-119.18)
y_lat_extent = (36.80,36.96)

# %%
product = 'l8_kline'
ds = dc.load(product=product,
             x = x_lon_extent, y =y_lat_extent,
             output_crs = 'epsg:32610', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )
# Out:
# Failed to resolve driver datacube.plugins.io.read::s3aio
# Failed to resolve driver datacube.plugins.io.read::s3aio_test

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 132, x: 797, y: 623)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-01-22T18:41:02.082476 ... 2015-12-27T18:40:01.598828
#   * y        (y) float64 4.097e+06 4.097e+06 4.097e+06 ... 4.079e+06 4.079e+06
#   * x        (x) float64 8.17e+05 8.17e+05 8.17e+05 ... 8.408e+05 8.409e+05
# Data variables:
#     red      (time, y, x) int16 -9999 -9999 -9999 -9999 ... -9999 -9999 -9999
#     green    (time, y, x) int16 -9999 -9999 -9999 -9999 ... -9999 -9999 -9999
#     blue     (time, y, x) int16 -9999 -9999 -9999 -9999 ... -9999 -9999 -9999
#     nir      (time, y, x) int16 -9999 -9999 -9999 -9999 ... -9999 -9999 -9999
# Attributes:
#     crs:      epsg:32610

# %%
from noteLib import *
# %matplotlib inline
for t in range(3,15):
    cnt=t
    figsize=[6,6]
    plot_labeled_rgb(ds, t, cnt, figsize=figsize)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/exposure/exposure.py:129: RuntimeWarning: invalid value encountered in true_divide
#   img_cdf = img_cdf / float(img_cdf[-1])
