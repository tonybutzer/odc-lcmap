# %% [markdown]
# # Example notebook

# %%
! datacube --help
# Out:
# Usage: datacube [OPTIONS] COMMAND [ARGS]...
#
#   Data Cube command-line interface
#
# Options:
#   --version
#   -v, --verbose                   Use multiple times for more verbosity
#   --log-file TEXT                 Specify log file
#   -E, --env TEXT
#   -C, --config, --config_file TEXT
#   --log-queries                   Print database queries.
#   -h, --help                      Show this message and exit.
#
# Commands:
#   dataset        Dataset management commands
#   ingest         Ingest datasets
#   metadata_type  Metadata type commands
#   product        Product commands
#   system         System commands
#   user           User management commands

# %%
# ! sudo mkdir /data
# ! sudo chown ubuntu:ubuntu /data
# !aws s3 cp s3://lsaa-staging-cog/L5/2011/044/034/LT05_T2AL_044034_20110513_20170406_01_A1/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.TIF /data
# Out:
# fatal error: An error occurred (404) when calling the HeadObject operation: Key "L5/2011/044/034/LT05_T2AL_044034_20110513_20170406_01_A1/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.TIF" does not exist

# %%
# !gdalinfo /data/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.TIF
# Out:
# Driver: GTiff/GeoTIFF
# Files: /data/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.TIF
# Size is 8921, 8381
# Coordinate System is:
# PROJCS["Albers",
#     GEOGCS["WGS 84",
#         DATUM["WGS_1984",
#             SPHEROID["WGS 84",6378140,298.2569999999957,
#                 AUTHORITY["EPSG","7030"]],
#             AUTHORITY["EPSG","6326"]],
#         PRIMEM["Greenwich",0],
#         UNIT["degree",0.0174532925199433],
#         AUTHORITY["EPSG","4326"]],
#     PROJECTION["Albers_Conic_Equal_Area"],
#     PARAMETER["standard_parallel_1",29.5],
#     PARAMETER["standard_parallel_2",45.5],
#     PARAMETER["latitude_of_center",23],
#     PARAMETER["longitude_of_center",-96],
#     PARAMETER["false_easting",0],
#     PARAMETER["false_northing",0],
#     UNIT["metre",1,
#         AUTHORITY["EPSG","9001"]]]
# Origin = (-2394015.000000000000000,2042415.000000000000000)
# Pixel Size = (30.000000000000000,-30.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
# ...

# %%
# !datacube product list
# Out:
# 2018-12-05 15:01:04,634 6422 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
# description: Landsat 5 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 39
# instrument: TM
# lat: null
# lon: null
# name: l5_kline
# platform: LANDSAT_5
# product_type: USARD
# time: null
# ---
# description: Landsat 7 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 40
# instrument: ETM
# lat: null
# lon: null
# name: l7_kline
# platform: LANDSAT_7
# product_type: USARD
# time: null
# ---
# description: Landsat 8 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 41
# instrument: OLI_TIRS
# lat: null
# lon: null
# name: l8_kline
# platform: LANDSAT_8
# product_type: USARD
# time: null

# %%
import datacube
dc= datacube.Datacube()
# Out:
# Failed to resolve driver datacube.plugins.index::s3aio_index

# %%
# !datacube dataset search product ='l5_kline' |grep id |wc
# Out:
# 2018-12-05 15:01:07,011 6435 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
#    2250    4500   92250

# %%
dir(dc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_list_measurements',
#  'close',
#  'create_storage',
#  'find_datasets',
#  'find_datasets_lazy',
#  'group_datasets',
#  'index',
#  'list_measurements',
#  'list_products',
#  'load',
#  'load_data',
#  'measurement_data',
#  'product_data',
#  'product_observations',
#  'product_sources']

# %%
dc.list_measurements()
# Out:
#                                       aliases  dtype  \
# product  measurement
# l5_kline blue                  [band_1, blue]  int16
#          green                [band_2, green]  int16
#          red                    [band_3, red]  int16
#          nir                    [band_4, nir]  int16
#          swir1                [band_5, swir1]  int16
#          therm                  [btb6, therm]  int16
#          swir2                [band_7, swir2]  int16
#          pixel_qa         [PIXELQA, pixel_qa]  int16
# l7_kline blue                  [band_1, blue]  int16
#          green                [band_2, green]  int16
#          red                    [band_3, red]  int16
#          nir                    [band_4, nir]  int16
#          swir1                [band_5, swir1]  int16
#          therm                  [btb6, therm]  int16
#          swir2                [band_7, swir2]  int16
#          pixel_qa         [PIXELQA, pixel_qa]  int16
# ...

# %%
! datacube  product list
# Out:
# 2018-12-05 15:01:13,560 6447 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
# description: Landsat 5 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 39
# instrument: TM
# lat: null
# lon: null
# name: l5_kline
# platform: LANDSAT_5
# product_type: USARD
# time: null
# ---
# description: Landsat 7 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 40
# instrument: ETM
# lat: null
# lon: null
# name: l7_kline
# platform: LANDSAT_7
# product_type: USARD
# time: null
# ---
# description: Landsat 8 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 41
# instrument: OLI_TIRS
# lat: null
# lon: null
# name: l8_kline
# platform: LANDSAT_8
# product_type: USARD
# time: null

# %%
from datetime import datetime
date_range = (
        datetime(2014,5,20),
        datetime(2014,6,30))

# %%
product = 'l8_kline'
ds = dc.load(product=product,x = (-119.44,-119.18), y =(36.80,36.96),
             output_crs = 'epsg:32610', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )
# Out:
# Failed to resolve driver datacube.plugins.io.read::s3aio
# Failed to resolve driver datacube.plugins.io.read::s3aio_test
# Error opening source dataset: s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20170307_01_A1_sr_band4.TIF
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsis3/lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20170307_01_A1_sr_band4.TIF' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
! aws s3 ls lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20170307_01_A1_sr_band4.TIF

# %%
! aws s3 ls lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/
# Out:
# 2018-08-14 21:27:56      21751 LC08_L1TP_042034_20140523_20170307_01_A1.xml
# 2018-08-14 21:27:56     117287 LC08_L1TP_042034_20140523_20170307_01_A1_ANG.txt
# 2018-08-14 21:27:56       8804 LC08_L1TP_042034_20140523_20170307_01_A1_MTL.txt
# 2018-08-14 21:27:56      26793 LC08_L2SP_042034_20140523_20171310_01_A1.json
# 2018-08-14 21:27:56     146340 LC08_L2SP_042034_20140523_20171310_01_A1_ANG.json
# 2018-08-14 21:27:56       9660 LC08_L2SP_042034_20140523_20171310_01_A1_MTL.json
# 2018-08-14 21:27:56      11776 LC08_L2SP_042034_20140523_20171310_01_A1_bt_band10.IMD
# 2018-08-14 21:27:56   41682400 LC08_L2SP_042034_20140523_20171310_01_A1_bt_band10.TIF
# 2018-08-14 21:27:56    9909066 LC08_L2SP_042034_20140523_20171310_01_A1_bt_band10.TIF.ovr
# 2018-08-14 21:27:56      11776 LC08_L2SP_042034_20140523_20171310_01_A1_bt_band11.IMD
# 2018-08-14 21:27:56   40931540 LC08_L2SP_042034_20140523_20171310_01_A1_bt_band11.TIF
# ...

# %%
! aws s3 ls lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20170307_01_A1_sr_band4.TIF

! aws s3 ls lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20171310_01_A1_sr_band4.TIF
# Out:
# 2018-08-14 21:27:56   80382352 LC08_L2SP_042034_20140523_20171310_01_A1_sr_band4.TIF
# 2018-08-14 21:27:56   16054990 LC08_L2SP_042034_20140523_20171310_01_A1_sr_band4.TIF.ovr

# %%
! aws s3 cp  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L1TP_042034_20140523_20170307_01_A1.xml /data

# %%
# !cat /data/LC08_L1TP_042034_20140523_20170307_01_A1.xml

# %%
! aws s3 cp  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L2SP_042034_20140523_20171310_01_A1.json /data

# %%
# !cat /data/LC08_L2SP_042034_20140523_20171310_01_A1.json

# %%
! aws s3 cp  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L1TP_042034_20140523_20170307_01_A1_MTL.txt   /data
# Out:
# download: s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2SP_042034_20140523_20171310_01_A1/LC08_L1TP_042034_20140523_20170307_01_A1_MTL.txt to ../../../../data/LC08_L1TP_042034_20140523_20170307_01_A1_MTL.txt

# %%
# !cat /data/LC08_L1TP_042034_20140523_20170307_01_A1_MTL.txt
# Out:
# GROUP = L1_METADATA_FILE
#   GROUP = METADATA_FILE_INFO
#     ORIGIN = "Image courtesy of the U.S. Geological Survey"
#     REQUEST_ID = "0701703077034_00050"
#     LANDSAT_SCENE_ID = "LC80420342014143LGN01"
#     LANDSAT_PRODUCT_ID = "LC08_L1TP_042034_20140523_20170307_01_A1"
#     COLLECTION_NUMBER = 01
#     FILE_DATE = 2017-03-07T13:13:54Z
#     STATION_ID = "LGN"
#     PROCESSING_SOFTWARE_VERSION = "LPGS_2.7.0"
#   END_GROUP = METADATA_FILE_INFO
#   GROUP = PRODUCT_METADATA
#     DATA_TYPE = "L1TP"
#     COLLECTION_CATEGORY = "A1"
#     ELEVATION_SOURCE = "GLS2000"
#     OUTPUT_FORMAT = "GEOTIFF"
#     SPACECRAFT_ID = "LANDSAT_8"
#     SENSOR_ID = "OLI_TIRS"
#     WRS_PATH = 42
#     WRS_ROW = 34
#     NADIR_OFFNADIR = "NADIR"
#     TARGET_WRS_PATH = 42
#     TARGET_WRS_ROW = 34
#     DATE_ACQUIRED = 2014-05-23
#     SCENE_CENTER_TIME = "18:33:12.6667770Z"
#     CORNER_UL_LAT_PRODUCT = 38.32476
#     CORNER_UL_LON_PRODUCT = -120.81501
#     CORNER_UR_LAT_PRODUCT = 38.88567
# ...

# %%
! (cd /data && grep sr_band4 *.xml *.json *MTL*)
# Out:
# LC08_L1TP_042034_20140523_20170307_01_A1.xml:        <band product="sr_refl" name="sr_band4" category="image" data_type="INT16" nlines="8801" nsamps="8611" fill_value="-9999" scale_factor="0.000100">
# LC08_L1TP_042034_20140523_20170307_01_A1.xml:            <file_name>LC08_L1TP_042034_20140523_20170307_01_A1_sr_band4.tif</file_name>
# LC08_L2SP_042034_20140523_20171310_01_A1.json:          "@name": "sr_band4",
# LC08_L2SP_042034_20140523_20171310_01_A1.json:          "file_name": "LC08_L2SP_042034_20140523_20171310_01_A1_sr_band4.tif",

# %% [markdown]
# # name="sr_band1"
#
# ## <file_name>LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.tif</file_name>
#
# - lower case .tif does not exist - so why point to it in the XML

# %%
# !aws s3 ls s3://lsaa-test-cog/L5/2011/044/034/LT05_T2AL_044034_20110513_20170406_01_A1/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.tif

# %%
# !aws s3 ls s3://lsaa-test-cog/L5/2011/044/034/LT05_T2AL_044034_20110513_20170406_01_A1/LT05_L1TP_044034_20110513_20161102_01_A1_sr_band1.TIF

# %%
ds

# %%
from noteLib import *
# %matplotlib inline
for t in range(3,9):
    cnt=t
    figsize=[6,6]
    plot_labeled_rgb(ds, t, cnt, figsize=figsize)

# %%
ds.y[3].values

# %%
ds.x[3].values

# %%
x = (-119.44,-119.18)
y =(36.80,36.96)

# %%
m = display_map(y,x)

# %%
m
