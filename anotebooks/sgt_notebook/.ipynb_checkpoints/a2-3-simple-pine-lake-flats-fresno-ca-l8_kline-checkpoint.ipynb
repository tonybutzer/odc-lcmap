# %% [markdown]
# # Example notebook

# %%
import datacube
dc= datacube.Datacube()
# Out:
# Failed to resolve driver datacube.plugins.index::s3aio_index

# %%
# !datacube dataset search product ='l7_kline' |grep id |wc
# Out:
# 2018-11-28 20:21:45,032 14949 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
#    1830    3660   75030

# %%
dc.list_measurements()
# Out:
#                                       aliases  dtype  \
# product  measurement
# l5_kline blue                  [band_1, blue]  int16
#          green                [band_2, green]  int16
#          red                    [band_3, red]  int16
#          nir                    [band_4, nir]  int16
#          swir1                [band_5, swir1]  int16
#          therm                  [btb6, therm]  int16
#          swir2                [band_7, swir2]  int16
#          pixel_qa         [PIXELQA, pixel_qa]  int16
# l7_kline blue                  [band_1, blue]  int16
#          green                [band_2, green]  int16
#          red                    [band_3, red]  int16
#          nir                    [band_4, nir]  int16
#          swir1                [band_5, swir1]  int16
#          therm                  [btb6, therm]  int16
#          swir2                [band_7, swir2]  int16
#          pixel_qa         [PIXELQA, pixel_qa]  int16
# l8_kline sr_band1          [band_1, sr_band1]  int16
#          blue                  [band_2, blue]  int16
#          green                [band_3, green]  int16
#          red                    [band_4, red]  int16
#          nir                    [band_5, nir]  int16
#          swir1                [band_6, swir1]  int16
#          swir2                [band_7, swir2]  int16
#          panchromatic  [band_8, panchromatic]  int16
#          cirrus              [band_9, cirrus]  int16
#          lwir1               [band_10, lwir1]  int16
#          lwir2               [band_11, lwir2]  int16
#          therm                 [btb10, therm]  int16
#          pixel_qa         [PIXELQA, pixel_qa]  int16
#
#                                                         flags_definition  \
# product  measurement
# l5_kline blue                                                        NaN
#          green                                                       NaN
#          red                                                         NaN
#          nir                                                         NaN
#          swir1                                                       NaN
#          therm                                                       NaN
#          swir2                                                       NaN
#          pixel_qa      {'cloud': {'bits': [4], 'values': {'0': False,...
# l7_kline blue                                                        NaN
#          green                                                       NaN
#          red                                                         NaN
#          nir                                                         NaN
#          swir1                                                       NaN
#          therm                                                       NaN
#          swir2                                                       NaN
#          pixel_qa      {'cloud': {'bits': [4], 'values': {'0': False,...
# l8_kline sr_band1                                                    NaN
#          blue                                                        NaN
#          green                                                       NaN
#          red                                                         NaN
#          nir                                                         NaN
#          swir1                                                       NaN
#          swir2                                                       NaN
#          panchromatic                                                NaN
#          cirrus                                                      NaN
#          lwir1                                                       NaN
#          lwir2                                                       NaN
#          therm                                                       NaN
#          pixel_qa      {'fill': {'bits': [0], 'values': {'0': False, ...
#
#                                name  nodata units
# product  measurement
# l5_kline blue                  blue   -9999     1
#          green                green   -9999     1
#          red                    red   -9999     1
#          nir                    nir   -9999     1
#          swir1                swir1   -9999     1
#          therm                therm   -9999     1
#          swir2                swir2   -9999     1
#          pixel_qa          pixel_qa       0     1
# l7_kline blue                  blue   -9999     1
#          green                green   -9999     1
#          red                    red   -9999     1
#          nir                    nir   -9999     1
#          swir1                swir1   -9999     1
#          therm                therm   -9999     1
#          swir2                swir2   -9999     1
#          pixel_qa          pixel_qa       0     1
# l8_kline sr_band1          sr_band1   -9999     1
#          blue                  blue   -9999     1
#          green                green   -9999     1
#          red                    red   -9999     1
#          nir                    nir   -9999     1
#          swir1                swir1   -9999     1
#          swir2                swir2   -9999     1
#          panchromatic  panchromatic   -9999     1
#          cirrus              cirrus   -9999     1
#          lwir1                lwir1   -9999     1
#          lwir2                lwir2   -9999     1
#          therm                therm   -9999     1
#          pixel_qa          pixel_qa       0     1

# %%
! datacube  product list
# Out:
# 2018-11-28 20:21:50,445 14963 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
# description: Landsat 5 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 26
# instrument: TM
# lat: null
# lon: null
# name: l5_kline
# platform: LANDSAT_5
# product_type: USARD
# time: null
# ---
# description: Landsat 7 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 27
# instrument: ETM
# lat: null
# lon: null
# name: l7_kline
# platform: LANDSAT_7
# product_type: USARD
# time: null
# ---
# description: Landsat 8 ARD California Product Definition - Kristi Kline LSAA
# format: GeoTiff
# id: 28
# instrument: OLI_TIRS
# lat: null
# lon: null
# name: l8_kline
# platform: LANDSAT_8
# product_type: USARD
# time: null

# %%
from datetime import datetime
date_range = (
        datetime(2000,1,20),
        datetime(2001,12,31))

# %%
x_lon_extent = (-119.44,-119.18)
y_lat_extent = (36.80,36.96)

# %%
product = 'l7_kline'
ds = dc.load(product=product,
             x = x_lon_extent, y =y_lat_extent,
             output_crs = 'epsg:32610', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )
# Out:
# Failed to resolve driver datacube.plugins.io.read::s3aio
# Failed to resolve driver datacube.plugins.io.read::s3aio_test

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 124, x: 797, y: 623)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-02-02T18:26:30.055246 ... 2001-12-21T18:22:47.884151
#   * y        (y) float64 4.097e+06 4.097e+06 4.097e+06 ... 4.079e+06 4.079e+06
#   * x        (x) float64 8.17e+05 8.17e+05 8.17e+05 ... 8.408e+05 8.409e+05
# Data variables:
#     red      (time, y, x) int16 625 569 540 426 455 ... 3524 4071 3934 4003 4173
#     green    (time, y, x) int16 688 561 464 432 335 ... 3569 4068 3915 3953 4145
#     blue     (time, y, x) int16 470 412 382 412 323 ... 3596 4205 4037 4004 4240
#     nir      (time, y, x) int16 2153 1657 1236 892 738 ... 4375 4329 4329 4562
# Attributes:
#     crs:      epsg:32610

# %%
from noteLib import *
# %matplotlib inline
for t in range(3,15):
    cnt=t
    figsize=[6,6]
    plot_labeled_rgb(ds, t, cnt, figsize=figsize)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/exposure/exposure.py:129: RuntimeWarning: invalid value encountered in true_divide
#   img_cdf = img_cdf / float(img_cdf[-1])
