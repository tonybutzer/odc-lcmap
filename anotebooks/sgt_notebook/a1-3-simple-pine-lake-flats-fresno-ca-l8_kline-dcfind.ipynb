# %% [markdown]
# # Example notebook

# %%
import datacube
dc= datacube.Datacube()
# Out:
# Failed to resolve driver datacube.plugins.index::s3aio_index

# %%
dir(dc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_list_measurements',
#  'close',
#  'create_storage',
#  'find_datasets',
#  'find_datasets_lazy',
#  'group_datasets',
#  'index',
#  'list_measurements',
#  'list_products',
#  'load',
#  'load_data',
#  'measurement_data',
#  'product_data',
#  'product_observations',
#  'product_sources']

# %%
# !datacube dataset search product ='l8_kline' |grep id |wc
# Out:
# 2018-12-06 00:16:38,476 10144 datacube.drivers.driver_cache WARNING Failed to resolve driver datacube.plugins.index::s3aio_index
#     570    1140   23370

# %%
from datetime import datetime
date_range = (
        datetime(2015,1,20),
        datetime(2015,12,31))

# %%
x_lon_extent = (-119.44,-119.18)
y_lat_extent = (36.80,36.96)

# %%
product = 'l8_kline'
ds = dc.find_datasets(product=product,
             x = x_lon_extent, y =y_lat_extent,
             output_crs = 'epsg:32610', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )

# %%
myds = ds[0]

type(myds)
# Out:
# datacube.model.Dataset

# %%
print(len(ds))
# Out:
# 63

# %%
dir(myds)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'archived_time',
#  'bounds',
#  'center_time',
#  'crs',
#  'extent',
#  'format',
#  'id',
#  'indexed_by',
#  'indexed_time',
#  'is_active',
#  'is_archived',
#  'local_path',
#  'local_uri',
#  'managed',
#  'measurements',
#  'metadata',
#  'metadata_doc',
#  'metadata_type',
#  'sources',
#  'time',
#  'transform',
#  'type',
#  'uri_scheme',
#  'uris']

# %%
print(myds.crs)
# Out:
# epsg:5072

# %%
for uri in myds.uris:
    print(uri)
# Out:
# s3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1.json

# %%
print (myds.measurements)
# Out:
# {'nir': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band5.tif', 'layer': 1}, 'red': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band4.tif', 'layer': 1}, 'blue': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band2.tif', 'layer': 1}, 'green': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band3.tif', 'layer': 1}, 'swir1': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band6.tif', 'layer': 1}, 'swir2': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band7.tif', 'layer': 1}, 'therm': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_bt_band10.tif', 'layer': 1}, 'pixel_qa': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_pixel_qa.tif', 'layer': 1}, 'sr_band1': {'path': 's3://lsaa-staging-cog/L08/2015/042/034/LC08_L2SP_042034_20150203_20171210_01_A1/LC08_L2SP_042034_20150203_20171210_01_A1_sr_band1.tif', 'layer': 1}}

# %%
print(myds.extent)
# Out:
# Geometry({'type': 'Polygon', 'coordinates': [[(-2127300.0, 1714800.0), (-2127300.0, 1978800.0), (-1869300.0, 1978800.0), (-1869300.0, 1714800.0), (-2127300.0, 1714800.0)]]}, CRS('epsg:5072'))

# %%
print(myds.extent.type)
# Out:
# Polygon

# %%
print (type(myds.extent))
# Out:
# <class 'datacube.utils.geometry.Geometry'>

# %%
print (type(myds.extent.type))
# Out:
# <class 'str'>

# %%
print (myds.extent.boundingbox)
# Out:
# BoundingBox(left=-2127300.0, bottom=1714800.0, right=-1869300.0, top=1978800.0)

# %%
print (myds.extent.area)
# Out:
# 68112000000.0

# %%
print (myds.extent.boundary)
# Out:
# Geometry({'type': 'LineString', 'coordinates': [(-2127300.0, 1714800.0), (-2127300.0, 1978800.0), (-1869300.0, 1978800.0), (-1869300.0, 1714800.0), (-2127300.0, 1714800.0)]}, CRS('epsg:5072'))

# %%
print (myds.extent.boundary.type)
# Out:
# LineString

# %%
dir(myds.extent)
